# %%
from selenium import webdriver

# %%
# guild_name = input("길드 이름을 입력하세요: ")
# server = input("서버 이름을 입력하세요: ")

guild_name = "Alpha"
server = "크로아"
levels = []
members = []
dojangs = []
jobs = []

# %%
driver = webdriver.Chrome("chromedriver")

# %%
driver.get("https://maple.gg/")

# %%
search_box = driver.find_element_by_name("q")

# %%
search_box.send_keys(guild_name)

# %%
search_button = driver.find_element_by_css_selector("i.fa-search")
search_button.click()

# %%
guilds = driver.find_elements_by_css_selector("div.col-12")

# %%
# 이 부분 일반적이게 변경
driver.implicitly_wait(10)
# guild[0]을 변경해야함. 지금은 길드중에서 첫번째 길드만을 가져옴
finded_server = guilds[0].find_element_by_css_selector("div.search-result__item")
guild_server = finded_server.find_element_by_css_selector("b.font-size-14").text


if guild_server == server: #길드가 있는 서버와 검색한 서버가 같으면
    guild_button = driver.find_element_by_css_selector("div.col-12")
    guild_button.click()
    driver.implicitly_wait(5)
    numberOfMember = driver.find_elements_by_css_selector("div.col-lg-25 span")
    numberOfMember = int(numberOfMember[3].text[-4:-1])
    
    #길드원 container col-lg-3 col-md-6 col-sm-6 mt-4
    guild_member = driver.find_elements_by_css_selector("div.col-lg-3")
    
    for i in range(numberOfMember):
        try:
            guild_member_name = guild_member[i].find_element_by_css_selector("div.mb-2 a.font-size-14")
            guild_member_info = guild_member[i].find_element_by_css_selector("div.mb-2 span.font-size-12").text.split("/")

            members.append(guild_member_name.text)
            
            guild_member_job = guild_member_info[0]
            guild_member_level = guild_member_info[1]
            levels.append(int(guild_member_level[-3:]))
            jobs.append(guild_member_job[:10])
            print(guild_member_job, guild_member_level)
        except IndexError:
            break
# Out:
# 비숍 Lv.262
# 엔젤릭버스터 Lv.275
# 비숍 Lv.269
# 아크메이지(불,독) Lv.268
# 데몬슬레이어 Lv.258
# 아크메이지(불,독) Lv.258
# 나이트로드 Lv.254
# 나이트로드 Lv.243
# 섀도어 Lv.271
# 메카닉 Lv.268
# 윈드브레이커 Lv.266
# 바이퍼 Lv.264
# 플레임위자드 Lv.264
# 제로 Lv.262
# 패스파인더 Lv.261
# 바이퍼 Lv.261
# 듀얼블레이더 Lv.260
# 비숍 Lv.260
# 플레임위자드 Lv.260
# 루미너스 Lv.260
# 비숍 Lv.258
# 엔젤릭버스터 Lv.258
# 나이트로드 Lv.257
# 비숍 Lv.257
# 바이퍼 Lv.256
# 섀도어 Lv.256
# 듀얼블레이더 Lv.256
# 나이트로드 Lv.256
# 팬텀 Lv.255
# 에반 Lv.255
# 비숍 Lv.255
# 제로 Lv.255
# 제로 Lv.255
# 플레임위자드 Lv.255
# 팔라딘 Lv.255
# 플레임위자드 Lv.255
# 배틀메이지 Lv.255
# 메카닉 Lv.254
# 아크 Lv.254
# 제논 Lv.254
# 에반 Lv.254
# 키네시스 Lv.253
# 메르세데스 Lv.253
# 패스파인더 Lv.252
# 듀얼블레이더 Lv.252
# 은월 Lv.252
# 바이퍼 Lv.252
# 나이트로드 Lv.252
# 윈드브레이커 Lv.252
# 신궁 Lv.252
# 나이트로드 Lv.251
# 제로 Lv.251
# 배틀메이지 Lv.251
# 데몬슬레이어 Lv.251
# 보우마스터 Lv.251
# 아크 Lv.251
# 아크메이지(썬,콜) Lv.251
# 다크나이트 Lv.251
# 루미너스 Lv.250
# 데몬어벤져 Lv.250
# 다크나이트 Lv.235
# 바이퍼 Lv.234
# 데몬슬레이어 Lv.234
# 바이퍼 Lv.234
# 패스파인더 Lv.233
# 히어로 Lv.233
# 팬텀 Lv.233
# 엔젤릭버스터 Lv.233
# 메카닉 Lv.232
# 패스파인더 Lv.232
# 섀도어 Lv.232
# 나이트워커 Lv.232
# 아크메이지(썬,콜) Lv.231
# 팬텀 Lv.231
# 다크나이트 Lv.231
# 엔젤릭버스터 Lv.230
# 키네시스 Lv.228
# 패스파인더 Lv.225
# 루미너스 Lv.225

# %%
members
# Out:
# ['안나',
#  'Noble',
#  '수면',
#  '놈현',
#  '쌍도',
#  '렛잇고',
#  'Xeru',
#  '신캐리',
#  '우평화',
#  '병블캐리',
#  '사기캐',
#  '보르쮸',
#  '결정체',
#  'A제룬',
#  '청안룡',
#  'Action',
#  '씨쿠쿵',
#  '꽁꽁찌릿',
#  '201b',
#  '여고생재윤이',
#  '떡마나',
#  '의가사빌런',
#  '20090523',
#  '덤퀀',
#  '가고',
#  '셰익',
#  '분당존잘',
#  '이나경짱',
#  '한겨울의괴도',
#  '은빈',
#  '집안요정',
#  '힘개쎈놈',
#  '현량방정',
#  '하젤',
#  '이린츤',
#  '절망뿅',
#  '밴딩모멘트',
#  '김기',
#  '댕댕물개',
#  '레망',
#  '에젤리케',
#  'xzyxyzyxz',
#  '야릇해',
#  '십봉',
#  '최다애',
#  'Privacy',
#  '파보오오니',
#  '최토',
#  '아이짜아',
#  '테러비터',
#  '집권',
#  '토익',
#  '김혼밥',
#  '커여운람지',
#  '동글강아지',
#  '그이름을아크',
#  '축구나',
#  '입대천사',
#  '키즈유튜버',
#  '델쁨',
#  '썬갤',
#  '김그린클럽',
#  '박왕호',
#  '때애엑',
#  '나로여잉',
#  'Bless',
#  '아름답고굵은',
#  '사각이',
#  '현랑',
#  '간통',
#  'JuneBro',
#  '민잠',
#  '이두껑',
#  '노현무',
#  '04김예빈',
#  '떨었다',
#  '끅끅끅끅',
#  '덤비면원콤',
#  'Holy',
#  '먼미래바이퍼',
#  'URISS',
#  '신초랑',
#  '메소를새비지',
#  '쁘띠루미',
#  '갓세',
#  '순두킹',
#  '밤비나노',
#  '랑글이',
#  '기슥님',
#  '도가',
#  '냠는',
#  '폰은빈',
#  '서늘',
#  '용기DJ',
#  '너무마힛허',
#  '가쿠생',
#  '꼬북맛감자칩',
#  '오빠들연락줘',
#  '중력절',
#  '히키소녀',
#  '주구마',
#  '알삼',
#  '말랑쫄깃',
#  '늘찬란한',
#  '마인하이네',
#  '중뽕',
#  '뿔테',
#  '제성백',
#  '하늘아른거린',
#  '가화',
#  '룰리',
#  '령채군',
#  '서울일보',
#  '싸늘한단검',
#  '엿막어는반사',
#  '가벽',
#  '풋방고',
#  '구비',
#  '여인니',
#  '출시',
#  '소마재원zZ',
#  '빻은정',
#  '긁적긁적어딜',
#  '박보영갤',
#  'Vigilnate',
#  '아리타장',
#  '01년생백수',
#  '뎃콥',
#  '손목희생',
#  '벨파댄스',
#  '미하일투명',
#  '유정재',
#  'DOMINI0N',
#  'Xazu',
#  'Everest',
#  'Kikubaqudha',
#  '5jume',
#  '그래픽아트77',
#  '제너럴퐁',
#  '부성초일짱',
#  '충신패파',
#  '키스하기싫어',
#  '석컹',
#  '오디오트랙',
#  'Cross',
#  '세최나',
#  'Razah',
#  '랑아일체',
#  '랑능이',
#  'Hexa',
#  '강력살균력',
#  '작열소라빵',
#  '사파에',
#  '광진구문지기',
#  '도둑Go',
#  '별과야자수',
#  '잔다르크',
#  '챗이',
#  '찐교기',
#  '거미퀸',
#  '표봉탁',
#  '혜리너무',
#  '채퍼린',
#  '이고',
#  '오세아노',
#  '최종뎀16퍼',
#  '때리지마아영',
#  '플삐니',
#  'GLaDo5',
#  '윈브이뻐요',
#  '지존대거',
#  '마칭밴드',
#  '김컷잉',
#  '장전매콤주먹',
#  '수능왕',
#  '폭도',
#  '조시모스',
#  'IT는노노',
#  '운엉자',
#  '크림혼합',
#  '핫도그선장',
#  '크로아선발대',
#  '리응제',
#  '섹시유혹태오',
#  '동도담',
#  '릴리몬',
#  '알비요',
#  '메가추',
#  '지강새',
#  '17명지',
#  'Snanu',
#  '주근깨17만장',
#  '원더',
#  '박하얀',
#  '도넹',
#  'PsychicYuko',
#  '료비수',
#  '복매제']

# %% [markdown]
# 닉네임검색은 url상으로 maple.gg/u/안나 이런식으로 이루어진다. 이를 이용해서 셀레니움이 아닌 BeautifulSoup을 이용해서 할수도 있을듯.

# %%
div.py-0 h1.user-summary-floor

# %%
import requests
from bs4 import BeautifulSoup

# %%
response_anna = requests.get("https://maple.gg/안나")
html_anna = BeautifulSoup(reponse_anna.text,"html.parser")

dojang = html.select("div.py-0 h1.user-summary-floor")[0].text
print(dojang)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1a7b443bcb86> in <module>
#       1 response_anna = requests.get("https://maple.gg/안나")
# ----> 2 html_anna = BeautifulSoup(reponse_anna.text,"html.parser")
#       3
#       4 dojang = html.select("div.py-0 h1.user-summary-floor")[0].text
#       5 print(dojang)
#
# NameError: name 'reponse_anna' is not defined

# %%
for i in range(len(members)):
    response = requests.get("https://maple.gg/"+members[i])
    html = BeautifulSoup(response.text,"html.parser")
    
    try:
        dojang =

# %%
# 무릉층수 가져오기
from selenium.common.exceptions import NoSuchElementException

for i in range(len(members)):
    try:
        search_box = driver.find_element_by_name("q")
       
        search_box.send_keys(members[i])
    
        search_button = driver.find_element_by_css_selector("i.fa-search")
        search_button.click()
        driver.implicitly_wait(1)
        
        member_button = driver.find_elements_by_css_selector("div.search-result__item")[0]
        member_button.click()
    
    
        dojang = int(driver.find_elements_by_css_selector("h1.user-summary-floor")[0].text[-4:-2])
        print(i, members[i], dojang)
        dojangs.append(dojang)
        
    # 검색시 바로 캐릭터로 이동하는 경우
    except IndexError:
        try:
            dojang = int(driver.find_elements_by_css_selector("h1.user-summary-floor")[0].text[-4:-2])
            print(i,members[i], dojang)
            dojangs.append(dojang)
        
        # 무릉이 없는데 예전 무릉기록은 있음
        except IndexError:
            try:
                dojang = int(driver.find_element_by_css_selector("div.old-dojang").text[-3:-1])
                print(i,members[i], dojang)
                dojangs.append(dojang)
        
            # 무릉자체가 없음
            except NoSuchElementException:
                dojang = 0
                print(i,members[i], dojang)
                dojangs.append(dojang)
        
    except NoSuchElementException:
            dojang = 0
            print(i,members[i], dojang)
            dojangs.append(dojang)

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "member" : members,
    "level" : levels,
    "job" : jobs,
    "dojang" : dojangs
})

df.sort_values(by=["dojang"],axis=0,ascending=False)

# %%
df.to_excel(guild_name+".xlsx")

# %% [markdown]
# 보조직업: 플위, 배메, 제로, 은월 등
